# %%
import albumentations as A

policy = A.load('only_brightness.json')
policy
# Out:
# /home/lisihang/miniconda3/envs/ML/lib/python3.13/site-packages/albumentations/core/serialization.py:185: UserWarning: Argument(s) 'value, mask_value' are not valid for transform PadIfNeeded
#   return cls(**args)
# Compose([
#   LongestMaxSize(p=1.0, area_for_downscale=None, interpolation=1, mask_interpolation=0, max_size=[392], max_size_hw=None),
#   PadIfNeeded(p=1.0, border_mode=0, fill=0.0, fill_mask=0.0, min_height=392, min_width=392, pad_height_divisor=None, pad_width_divisor=None, padding=0, position='center'),
#   OneOf([
#     Sequential([
#       OneOf([
#         RandomBrightnessContrast(p=0.5226849913597107, brightness_by_max=True, brightness_limit=(0.14843523502349854, 0.14843523502349854), contrast_limit=(0.0, 0.0), ensure_safe_range=False),
#         NoOp(p=0.4773150086402893),
#       ], p=1.0),
#     ], p=1.0),
#   ], p=1),
#   Normalize(p=1.0, max_pixel_value=1.0, mean=(123.675, 116.28, 103.53), normalization='standard', std=(58.395, 57.12, 57.375)),
# ...

# %%
policy_dict = policy.to_dict()
policy_dict
# Out:
# {'__version__': '2.0.8',
#  'transform': {'__class_fullname__': 'Compose',
#   'p': 1.0,
#   'transforms': [{'__class_fullname__': 'LongestMaxSize',
#     'p': 1.0,
#     'area_for_downscale': None,
#     'interpolation': 1,
#     'mask_interpolation': 0,
#     'max_size': [392],
#     'max_size_hw': None},
#    {'__class_fullname__': 'PadIfNeeded',
#     'p': 1.0,
#     'border_mode': 0,
#     'fill': 0.0,
#     'fill_mask': 0.0,
#     'min_height': 392,
#     'min_width': 392,
#     'pad_height_divisor': None,
#     'pad_width_divisor': None,
#     'padding': 0,
#     'position': 'center'},
#    {'__class_fullname__': 'OneOf',
#     'p': 1,
#     'transforms': [{'__class_fullname__': 'Sequential',
#       'p': 1.0,
#       'transforms': [{'__class_fullname__': 'OneOf',
#         'p': 1.0,
#         'transforms': [{'__class_fullname__': 'RandomBrightnessContrast',
#           'p': 0.5226849913597107,
#           'brightness_by_max': True,
# ...

# %%
policy_dict['transform']
# Out:
# {'__class_fullname__': 'Compose',
#  'p': 1.0,
#  'transforms': [{'__class_fullname__': 'LongestMaxSize',
#    'p': 1.0,
#    'area_for_downscale': None,
#    'interpolation': 1,
#    'mask_interpolation': 0,
#    'max_size': [392],
#    'max_size_hw': None},
#   {'__class_fullname__': 'PadIfNeeded',
#    'p': 1.0,
#    'border_mode': 0,
#    'fill': 0.0,
#    'fill_mask': 0.0,
#    'min_height': 392,
#    'min_width': 392,
#    'pad_height_divisor': None,
#    'pad_width_divisor': None,
#    'padding': 0,
#    'position': 'center'},
#   {'__class_fullname__': 'OneOf',
#    'p': 1,
#    'transforms': [{'__class_fullname__': 'Sequential',
#      'p': 1.0,
#      'transforms': [{'__class_fullname__': 'OneOf',
#        'p': 1.0,
#        'transforms': [{'__class_fullname__': 'RandomBrightnessContrast',
#          'p': 0.5226849913597107,
#          'brightness_by_max': True,
#          'brightness_limit': (0.14843523502349854, 0.14843523502349854),
# ...

# %%
a = policy.transforms[2:-2]

# %%
type(a)
# Out:
# list
